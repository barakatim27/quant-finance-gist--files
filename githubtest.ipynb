# %% [markdown]
# <a href="https://colab.research.google.com/github/barakatim27/quant-finance-gist--files/blob/main/githubtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_tuple = (1, 2, 3, 4, 5)
my_tuple[0] = 40
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_535/2311158526.py in <cell line: 0>()
#       1 my_tuple = (1, 2, 3, 4, 5)
# ----> 2 my_tuple[0] = 40
#
# TypeError: 'tuple' object does not support item assignment
