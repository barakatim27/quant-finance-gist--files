# %% [markdown]
# <a href="https://colab.research.google.com/github/barakatim27/quant-finance-gist--files/blob/main/Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [5, 10, 15, 20, 25]

total = 0

for num in numbers:
    total += num

mean = total / len(numbers)

print("Numbers:", numbers)
print("Mean:",mean)
print("Max:", max(numbers))
print("Min:", min(numbers))
# Out:
# Numbers: [5, 10, 15, 20, 25]
# Mean: 15.0
# Max: 25
# Min: 5
